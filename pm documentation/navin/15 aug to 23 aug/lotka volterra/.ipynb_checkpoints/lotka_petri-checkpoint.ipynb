# %% [markdown]
# Necessary Imports:
#
# Catlab provides support for Categorical Algebra used by other libraries
# AlgebraicPetri and AlgebraicDynamics are essential for petri-net modelling of dynamical systems
# They interface petri-nets with categorical constructs with "vectorfields"
#
# Differential Equations, Plots for obvious reasons, LabelledArrays provide support for "labelled" vectors

# %%
using Catlab, Catlab.CategoricalAlgebra, Catlab.Programs, Catlab.WiringDiagrams, Catlab.Graphics 
using AlgebraicPetri 
using AlgebraicDynamics.UWDDynam 

using DifferentialEquations 

using LabelledArrays 
using Plots

# %% [markdown]
# LabelledPetriNet essentially adds names to every object in the FinSet representing TISO of the PetriNet
# Open is a transform taking the labelled petri net to a structured multi cospan (turning the closed system into an exposed and open one)

# %%
# A Lotka Volterra Model dealing with Foxes and Rabbits
LV = Open(LabelledPetriNet(
    [:Fox, :Rabbit], 
    :birth_rabbit => ((:Rabbit) => (:Rabbit, :Rabbit)),
    :death_fox => ((:Fox) => ()),
    :predation_rabbit => ((:Rabbit, :Fox) => (:Fox, :Fox))
    ))

# Navin's Pigeon Model
N = Open(LabelledPetriNet([:Fox, :Pigeon], 
    :birth_pigeon => ((:Pigeon) => (:Pigeon, :Pigeon)),
    :death_pigeon => ((:Pigeon) => ()),
    :pigeon_eaten => ((:Pigeon, :Fox) => (:Fox))
)
)

# Aditi's Bear Model
A = Open(LabelledPetriNet([:Fox, :Bear], 
    :birth_bear => ((:Bear) => (:Bear, :Bear)),
    :death_bear => ((:Bear) => ()),
    :predation_fox => ((:Bear, :Fox) => (:Bear, :Bear))
)
)

# Shivanshu's Fish Model
S = Open(LabelledPetriNet([:Fox, :Bear, :Fish], 
    :birth_fish => ((:Fish) => (:Fish, :Fish)),
    :predation_fish_bear => ((:Fish, :Bear) => (:Bear, :Bear)),
    :predation_fish_fox => ((:Fish, :Fox) => (:Fox))
)
)

# Achintya's Cat Model
Ac = Open(LabelledPetriNet([:Cat, :Fish, :Pigeon], 
    :birth_cat => ((:Cat) => (:Cat, :Cat)),
    :predation_fish_cat => ((:Fish, :Cat) => (:Cat, :Cat)),
    :predation_pigeon_cat => ((:Pigeon, :Cat) => (:Cat, :Cat)),
    :death_cat => ((:Cat)=>())
)
)

# Madhav's lion Model
ML = Open(LabelledPetriNet([:Lion, :Cat, :Rabbit, :Fox], 
:predation_cat_lion => ((:Lion, :Cat) => (:Lion, :Lion)),
:predation_rabbit_lion => ((:Lion, :Rabbit) => (:Lion, :Lion)),
:predation_fox_lion => ((:Lion, :Fox) => (:Lion, :Lion)),
    :death_lion => ((:Lion)=>())
)
)
# Out:
# StructuredMulticospan{Catlab.CategoricalAlgebra.StructuredCospans.DiscreteACSet{AnonACSet{TypeLevelBasicSchema{Symbol, Tuple{:S}, Tuple{}, Tuple{:Name}, Tuple{(:sname, :S, :Name)}, Tuple{}}, Tuple{Symbol}, @NamedTuple{S::IntParts, Name::IntParts}, @NamedTuple{sname::ACSets.ColumnImplementations.DenseColumn{Union{AttrVar, Symbol}, Vector{Union{AttrVar, Symbol}}}}, IntParts}, LabelledPetriNet}, SMulticospan{4, LabelledPetriNet, StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:T, :S, :I, :O}, Tuple{(:it, :I, :T), (:is, :I, :S), (:ot, :O, :T), (:os, :O, :S)}, Tuple{:Name}, Tuple{(:tname, :T, :Name), (:sname, :S, :Name)}, Tuple{}}, @NamedTuple{T::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, S::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, I::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, O::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Name::VarFunction{Symbol}}, LabelledPetriNet, LabelledPetriNet}, StaticArraysCore.SVector{4, StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:T, :S, :I, :O}, Tuple{(:it, :I, :T), (:is, :I, :S), (:ot, :O, :T), (:os, :O, :S)}, Tuple{:Name}, Tuple{(:tname, :T, :Name), (:sname, :S, :Name)}, Tuple{}}, @NamedTuple{T::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, S::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, I::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, O::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Name::VarFunction{Symbol}}, LabelledPetriNet, LabelledPetriNet}}}, StaticArraysCore.SVector{4, AnonACSet{TypeLevelBasicSchema{Symbol, Tuple{:S}, Tuple{}, Tuple{:Name}, Tuple{(:sname, :S, :Name)}, Tuple{}}, Tuple{Symbol}, @NamedTuple{S::IntParts, Name::IntParts}, @NamedTuple{sname::ACSets.ColumnImplementations.DenseColumn{Union{AttrVar, Symbol}, Vector{Union{AttrVar, Symbol}}}}, IntParts}}}(SMulticospan{4, LabelledPetriNet, StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:T, :S, :I, :O}, Tuple{(:it, :I, :T), (:is, :I, :S), (:ot, :O, :T), (:os, :O, :S)}, Tuple{:Name}, Tuple{(:tname, :T, :Name), (:sname, :S, :Name)}, Tuple{}}, @NamedTuple{T::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, S::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, I::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, O::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Name::VarFunction{Symbol}}, LabelledPetriNet, LabelledPetriNet}, StaticArraysCore.SVector{4, StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:T, :S, :I, :O}, Tuple{(:it, :I, :T), (:is, :I, :S), (:ot, :O, :T), (:os, :O, :S)}, Tuple{:Name}, Tuple{(:tname, :T, :Name), (:sname, :S, :Name)}, Tuple{}}, @NamedTuple{T::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, S::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, I::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, O::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, N ...
#   T = 1:4
#   S = 1:4
#   I = 1:7
#   O = 1:6
#   Name = 1:0
#   it : I → T = [1, 1, 2, 2, 3, 3, 4]
#   is : I → S = [1, 2, 1, 3, 1, 4, 1]
#   ot : O → T = [1, 1, 2, 2, 3, 3]
#   os : O → S = [1, 1, 1, 1, 1, 1]
#   tname : T → Name = [:predation_cat_lion, :predation_rabbit_lion, :predation_fox_lion, :death_lion]
#   sname : S → Name = [:Lion, :Cat, :Rabbit, :Fox], StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:T, :S, :I, :O}, Tuple{(:it, :I, :T), (:is, :I, :S), (:ot, :O, :T), (:os, :O, :S)}, Tuple{:Name}, Tuple{(:tname, :T, :Name), (:sname, :S, :Name)}, Tuple{}}, @NamedTuple{T::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, S::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, I::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, O::Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Name::VarFunction{Symbol}}, LabelledPetriNet, LabelledPetriNet}[ACSetTransformation((T = FinFunction(Int64[], 0, 4), S = FinFunction([1], 1, 4), I = FinFunction(Int64[], 0, 7), O = FinFunction(Int64[], 0, 6), Name = VarFunction{Symbol}(FinDomFunction(Union{AttrVar, Symbol}[], FinSet(0), TypeSet(Union{AttrVar, Symbol})), FinSet(0))), LabelledPetriNet {T:0, S:1, I:0, O:0, Name:0}, LabelledPetriNet {T:4, S:4, I:7, O:6, Name:0}), ACSetTransformation((T = FinFunction(Int64[], 0, 4), S = FinFunction([2], 1, 4), I = FinFunction(Int64[], 0, 7), O = FinFunction(Int64[], 0, 6), Name = VarFunction{Symbol}(FinDomFunction(Union{AttrVar, Symbol}[], FinSet(0), TypeSet(Union{AttrVar, Symbol})), FinSet(0))), LabelledPetriNet {T:0, S:1, I:0, O:0, Name:0}, LabelledPetriNet {T:4, S:4, I:7, O:6, Name:0}), ACSetTransformation((T = FinFunction(Int64[], 0, 4), S = FinFunction([3], 1, 4), I = FinFunction(Int64[], 0, 7), O = FinFunction(Int64[], 0, 6), Name = VarFunction{Symbol}(FinDomFunction(Union{AttrVar, Symbol}[], FinSet(0), TypeSet(Union{AttrVar, Symbol})), FinSet(0))), LabelledPetriNet {T:0, S:1, I:0, O:0, Name:0}, LabelledPetriNet {T:4, S:4, I:7, O:6, Name:0}), ACSetTransformation((T = FinFunction(Int64[], 0, 4), S = FinFunction([4], 1, 4), I = FinFunction(Int64[], 0, 7), O = FinFunction(Int64[], 0, 6), Name = VarFunction{Symbol}(FinDomFunction(Union{AttrVar, Symbol}[], FinSet(0), TypeSet(Union{AttrVar, Symbol})), FinSet(0))), LabelledPetriNet {T:0, S:1, I:0, O:0, Name:0}, LabelledPetriNet {T:4, S:4, I:7, O:6, Name:0})]), AnonACSet{TypeLevelBasicSchema{Symbol, Tuple{:S}, Tuple{}, Tuple{:Name}, Tuple{(:sname, :S, :Name)}, Tuple{}}, Tuple{Symbol}, @NamedTuple{S::IntParts, Name::IntParts}, @NamedTuple{sname::ACSets.ColumnImplementations.DenseColumn{Union{AttrVar, Symbol}, Vector{Union{AttrVar, Symbol}}}}, IntParts}[AnonACSet{TypeLevelBasicSchema{Symbol, Tuple{:S}, Tuple{}, Tuple{:Name}, Tuple{(:sname, :S, :Name)}, Tuple{}}, Tuple{Symbol}, @NamedTuple{S::IntParts, Name::IntParts}, @NamedTuple{sname::ACSets.ColumnImplementations.DenseColumn{Union{AttrVar, Symbol}, Vector{Union{AttrVar, Symbol}}}}, IntParts}:
#   S = 1:1
#   Name = 1:0
#   sname : S → Name = [:Lion], AnonACSet{TypeLevelBasicSchema{Symbol, Tuple{:S}, Tuple{}, Tuple{:Name}, Tuple{(:sname, :S, :Name)}, Tuple{}}, Tuple{Symbol}, @NamedTuple{S::IntParts, Name::IntParts}, @NamedTuple{sname::ACSets.ColumnImplementations.DenseColumn{Union{AttrVar, Symbol}, Vector{Union{AttrVar, Symbol}}}}, IntParts}:
#   S = 1:1
#   Name = 1:0
#   sname : S → Name = [:Cat], AnonACSet{TypeLevelBasicSchema{Symbol, Tuple{:S}, Tuple{}, Tuple{:Name}, Tuple{(:sname, :S, :Name)}, Tuple{}}, Tuple{Symbol}, @NamedTuple{S::IntParts, Name::IntParts}, @NamedTuple{sname::ACSets.ColumnImplementations.DenseColumn{Union{AttrVar, Symbol}, Vector{Union{AttrVar, Symbol}}}}, IntParts}:
#   S = 1:1
#   Name = 1:0
#   sname : S → Name = [:Rabbit], AnonACSet{TypeLevelBasicSchema{Symbol, Tuple{:S}, Tuple{}, Tuple{:Name}, Tuple{(:sname, :S, :Name)}, Tuple{}}, Tuple{Symbol}, @NamedTuple{S::IntParts, Name::IntParts}, @NamedTuple{sname::ACSets.ColumnImplementations.DenseColumn{Union{AttrVar, Symbol}, Vector{Union{AttrVar, Symbol}}}}, IntParts}:
#   S = 1:1
#   Name = 1:0
#   sname : S → Name = [:Fox]])

# %%
Here we create a UWD which provides the operad algebra used to compose the structured multi cospans

# %%
forest_composition_pattern = @relation (Foxes, Pigeons, Rabbits, Bears, Fish, Cat, Lion) where (Foxes, Pigeons, Rabbits, Bears, Fish, Cat, Lion) begin
    lotka(Foxes, Rabbits)
    navin(Foxes, Pigeons)
    aditi(Foxes, Bears)
    shivanshu(Foxes, Bears, Fish)
    achintya(Cat, Fish, Pigeons)
    madhav(Lion, Cat, Rabbits, Foxes)
end 

to_graphviz(forest_composition_pattern, box_labels = :name, junction_labels = :variable)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", false, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box1", :label => "lotka")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box2", :label => "navin")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box3", :label => "aditi")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box4", :label => "shivanshu")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box5", :label => "achintya")), Catlab.Graphics.Graphviz.Node("n6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box6", :label => "madhav")), Catlab.Graphics.Graphviz.Node("n7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer1", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n8", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer2", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n9", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer3", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n10", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer4", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0"))  …  Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n17", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n10", "", ""), Catlab.Graphics.Graphviz.NodeID("n17", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n18", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n18", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n11", "", ""), Catlab.Graphics.Graphviz.NodeID("n18", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n19", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n6", "", ""), Catlab.Graphics.Graphviz.NodeID("n19", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n12", "", ""), Catlab.Graphics.Graphviz.NodeID("n19", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edg ...

# %%
forest_composite = oapply(forest_composition_pattern, 
    Dict(   :lotka => LV,   :navin => N, :aditi => A, :shivanshu => S, :achintya => Ac, :madhav => ML )
)

to_graphviz(forest_composite, program="neato")
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#6C9AC3", :label => "Fox", :shape => "circle")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#6C9AC3", :label => "Rabbit", :shape => "circle")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#6C9AC3", :label => "Pigeon", :shape => "circle")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#6C9AC3", :label => "Bear", :shape => "circle")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#6C9AC3", :label => "Fish", :shape => "circle")), Catlab.Graphics.Graphviz.Node("n6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#6C9AC3", :label => "Cat", :shape => "circle")), Catlab.Graphics.Graphviz.Node("n7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#6C9AC3", :label => "Lion", :shape => "circle")), Catlab.Graphics.Graphviz.Node("n8", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#E28F41", :label => "birth_rabbit", :shape => "square")), Catlab.Graphics.Graphviz.Node("n9", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#E28F41", :label => "death_fox", :shape => "square")), Catlab.Graphics.Graphviz.Node("n10", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#E28F41", :label => "predation_rabbit", :shape => "square"))  …  Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n16", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n6", "", ""), Catlab.Graphics.Graphviz.NodeID("n24", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n11", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n13", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n17", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n18", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n11", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n18", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:l ...

# %%
prey_reproduction_dynamics = ContinuousResourceSharer{Float64}(1, 1, (u, p, t) -> p.alpha * u, [1])
predator_death_dynamics = ContinuousResourceSharer{Float64}(1, 1, (u, p, t) -> -p.gamma * u, [1])
fair_predation_dynamics = ContinuousResourceSharer{Float64}(2, 2, (u, p, t) -> [p.delta * u[1] * u[2], -p.beta * u[1] * u[2]], [1, 2])
unfair_predation_dynamics = ContinuousResourceSharer{Float64}(2, 2, (u, p, t) -> [0, -p.beta * u[1] * u[2]], [1, 2])
# Out:
# ContinuousResourceSharer(ℝ^2 → ℝ^2) with 2 exposed ports

# %%
lotka_composition_pattern = @relation (Fox, Rabbit) where (Fox, Rabbit) begin   
    birth(Rabbit)   
    predation(Fox, Rabbit)   
    death(Fox) 
end  

to_graphviz(lotka_composition_pattern,  box_labels = :name, junction_labels = :variable)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", false, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box1", :label => "birth")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box2", :label => "predation")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box3", :label => "death")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer1", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer2", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:comment => "junction", :fillcolor => "black", :height => "0.075", :id => "junction1", :label => "", :shape => "circle", :style => "filled", :width => "0.075", :xlabel => "Fox")), Catlab.Graphics.Graphviz.Node("n7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:comment => "junction", :fillcolor => "black", :height => "0.075", :id => "junction2", :label => "", :shape => "circle", :style => "filled", :width => "0.075", :xlabel => "Rabbit")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif", :shape => "ellipse", :margin => "0.05,0.025", :width => "0.5", :height => "0.5"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif", :len => "0.5"))

# %%
navin_composition_pattern = @relation (Fox, Pigeon) where (Fox, Pigeon) begin   
    birth(Pigeon)   
    sad_predation(Fox, Pigeon)   
    death(Fox) 
end  

to_graphviz(navin_composition_pattern,  box_labels = :name, junction_labels = :variable)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", false, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box1", :label => "birth")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box2", :label => "sad_predation")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box3", :label => "death")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer1", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer2", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:comment => "junction", :fillcolor => "black", :height => "0.075", :id => "junction1", :label => "", :shape => "circle", :style => "filled", :width => "0.075", :xlabel => "Fox")), Catlab.Graphics.Graphviz.Node("n7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:comment => "junction", :fillcolor => "black", :height => "0.075", :id => "junction2", :label => "", :shape => "circle", :style => "filled", :width => "0.075", :xlabel => "Pigeon")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif", :shape => "ellipse", :margin => "0.05,0.025", :width => "0.5", :height => "0.5"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif", :len => "0.5"))

# %%
fox_death_pattern = @relation (Fox,) begin
    death(Fox) 
end  

to_graphviz(fox_death_pattern,  box_labels = :name, junction_labels = :variable)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", false, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box1", :label => "death")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :id => "outer1", :label => "", :margin => "0", :shape => "none", :style => "invis", :width => "0")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:comment => "junction", :fillcolor => "black", :height => "0.075", :id => "junction1", :label => "", :shape => "circle", :style => "filled", :width => "0.075", :xlabel => "Fox")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif", :shape => "ellipse", :margin => "0.05,0.025", :width => "0.5", :height => "0.5"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:fontname => "Serif", :len => "0.5"))

# %%
#TODO get UWD from petrinet forest joined at fox

# %%
p = LVector(birth_rabbit=3, birth_pigeon=2, death_fox=1, predation_rabbit=2, pigeon_eaten=3, death_pigeon=4, birth_bear = 1, death_bear = 1.1, predation_fox = 0.4, birth_fish=4, predation_fish_fox=20, predation_fish_bear=3, birth_cat=2, predation_fish_cat = 3, predation_pigeon_cat = 1, death_cat=3, death_lion = 1, predation_cat_lion = 2, predation_fox_lion = 3, predation_rabbit_lion = 10)
u0 = LVector(Fox=5, Rabbit=6, Pigeon=30, Bear =2, Fish=10, Cat=7, Lion=2)
soln = solve(ODEProblem(vectorfield(apex(forest_composite)), u0, (0.0, 100.0), p))
plot(soln)

# %%
apex(forest_composite)

# %%
LV
